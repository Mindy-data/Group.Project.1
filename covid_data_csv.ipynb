# %%
import pandas as pd

# %%
covid_df= pd.read_csv('Covid_data/owid-covid-data.csv')

# %%
north_america_covid_df= covid_df.loc[covid_df['continent']== 'North America']

# %%
usa_covid_df= covid_df.loc[covid_df['location']== 'United States']

# %%
usa_covid_df
# Out:
#        iso_code      continent       location        date  total_cases  \
# 334627      USA  North America  United States  2020-01-03          NaN
# 334628      USA  North America  United States  2020-01-04          NaN
# 334629      USA  North America  United States  2020-01-05          NaN
# 334630      USA  North America  United States  2020-01-06          NaN
# 334631      USA  North America  United States  2020-01-07          NaN
# ...         ...            ...            ...         ...          ...
# 336029      USA  North America  United States  2023-11-05  103436829.0
# 336030      USA  North America  United States  2023-11-06  103436829.0
# 336031      USA  North America  United States  2023-11-07  103436829.0
# 336032      USA  North America  United States  2023-11-08  103436829.0
# 336033      USA  North America  United States  2023-11-09  103436829.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...
